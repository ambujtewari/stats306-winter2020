# %% [markdown]
# In this notebook, we will cover:
#
# * [Grouped Summaries](#Grouped-Summaries)
# * [Pipes](#Pipes)
#
# Let us load up the `tidyverse` and `nycflights13` packages.

# %%
library(tidyverse)
library(nycflights13)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# # Grouped Summaries

# %% [markdown]
# `summarize()` can be used to summarize entire data frames by collapsing them into single number summaries.

# %%
summarize(flights, delay = mean(dep_delay))
# Out:
#   delay
# 1 NA

# %% [markdown]
# Oops, we got `NA` since most operations involving missing values yield missing values. We can ignore missing values like this.

# %%
summarize(flights, delay = mean(dep_delay, na.rm = TRUE))
# Out:
#   delay
# 1 12.63907

# %% [markdown]
# The usefulness of `summarize()` is greater when used in conjunction with `group_by()`.

# %%
by_month <- group_by(flights, month)
(monthly_delays <- summarize(by_month, delay = mean(dep_delay, na.rm = TRUE)))
# Out:
#    month delay
# 1   1    10.036665
# 2   2    10.816843
# 3   3    13.227076
# 4   4    13.938038
# 5   5    12.986859
# 6   6    20.846332
# 7   7    21.727787
# 8   8    12.611040
# 9   9     6.722476
# 10 10     6.243988
# 11 11     5.435362
# 12 12    16.576688

# %% [markdown]
# Many summarization functions are available:
#
# * Center: `mean(), median()`
# * Spread: `sd(), IQR(), mad()`
# * Range: `min(), max(), quantile()`
# * Position: `first(), last(), nth()`
# * Count: `n(), n_distinct()`
# * Logical: `any(), all()`

# %% [markdown]
# # Pipes

# %% [markdown]
# The above code can be written without the use of the intermediate variable `by_month` using pipes.

# %%
group_by(flights, month) %>%
    summarize(delay = mean(dep_delay, na.rm = TRUE))
# Out:
#    month delay
# 1   1    10.036665
# 2   2    10.816843
# 3   3    13.227076
# 4   4    13.938038
# 5   5    12.986859
# 6   6    20.846332
# 7   7    21.727787
# 8   8    12.611040
# 9   9     6.722476
# 10 10     6.243988
# 11 11     5.435362
# 12 12    16.576688

# %% [markdown]
# Pipes make it easy for the author and reader of the code to focus on which transformations are occuring.

# %%
# Without pipes
by_dest <- group_by(flights, dest)
dest_summary <- summarize(by_dest, count = n(), delay = mean(dep_delay, na.rm = TRUE))
(dest_summary_final <- arrange(dest_summary, desc(count)))
# Out:
#     dest count delay
# 1   ORD  17283 13.570484
# 2   ATL  17215 12.509824
# 3   LAX  16174  9.401344
# 4   BOS  15508  8.730613
# 5   MCO  14082 11.275998
# 6   CLT  14064  9.222879
# 7   SFO  13331 12.866289
# 8   FLL  12055 12.731104
# 9   MIA  11728  8.876558
# 10  DCA   9705 10.293000
# 11  DTW   9384 11.812252
# 12  DFW   8738  8.681909
# 13  RDU   8163 12.445870
# 14  TPA   7466 12.135007
# 15  DEN   7266 15.156228
# 16  IAH   7198 10.842179
# 17  MSP   7185 13.324806
# 18  PBI   6554 12.992918
# 19  BNA   6333 15.982471
# 20  LAS   5997  9.418819
# 21  SJU   5819  9.808841
# 22  IAD   5700 16.982935
# 23  BUF   4681 13.423951
# 24  PHX   4656 10.412926
# 25  CLE   4573 13.387931
# 26  STL   4339 16.010557
# 27  MDW   4113 18.589763
# 28  CVG   3941 19.520321
# 29  SEA   3923 10.725922
# 30  MSY   3799 14.249463
# ⋮   ⋮    ⋮     ⋮
# 76  BGR  375   19.475000
# 77  BUR  371   13.475676
# 78  PSE  365   10.146814
# 79  OKC  346   30.568807
# 80  SJC  329   10.103659
# 81  TUL  315   34.906355
# 82  OAK  312   13.344051
# 83  BHM  297   29.694853
# 84  SMF  284   18.691489
# 85  AVL  275    8.190114
# 86  ACK  265    6.456604
# 87  ABQ  254   13.740157
# 88  MVY  221    7.051643
# 89  EGE  213   15.495192
# 90  CRW  138   17.000000
# 91  CAE  116   35.570093
# 92  ILM  110   19.416667
# 93  TVC  101   22.083333
# 94  MYR   59   15.758621
# 95  CHO   52   21.391304
# 96  BZN   36   11.457143
# 97  JAC   25   26.545455
# 98  PSP   19   -2.944444
# 99  EYW   17    3.647059
# 100 HDN   15   12.285714
# 101 MTJ   15   17.642857
# 102 SBN   10   21.100000
# 103 ANC    8   12.875000
# 104 LEX    1   -9.000000
# 105 LGA    1         NaN

# %%
# With pipes
group_by(flights, dest) %>%
    summarize(count = n(), delay = mean(dep_delay, na.rm = TRUE)) %>%
    arrange(desc(count))
# Out:
#     dest count delay
# 1   ORD  17283 13.570484
# 2   ATL  17215 12.509824
# 3   LAX  16174  9.401344
# 4   BOS  15508  8.730613
# 5   MCO  14082 11.275998
# 6   CLT  14064  9.222879
# 7   SFO  13331 12.866289
# 8   FLL  12055 12.731104
# 9   MIA  11728  8.876558
# 10  DCA   9705 10.293000
# 11  DTW   9384 11.812252
# 12  DFW   8738  8.681909
# 13  RDU   8163 12.445870
# 14  TPA   7466 12.135007
# 15  DEN   7266 15.156228
# 16  IAH   7198 10.842179
# 17  MSP   7185 13.324806
# 18  PBI   6554 12.992918
# 19  BNA   6333 15.982471
# 20  LAS   5997  9.418819
# 21  SJU   5819  9.808841
# 22  IAD   5700 16.982935
# 23  BUF   4681 13.423951
# 24  PHX   4656 10.412926
# 25  CLE   4573 13.387931
# 26  STL   4339 16.010557
# 27  MDW   4113 18.589763
# 28  CVG   3941 19.520321
# 29  SEA   3923 10.725922
# 30  MSY   3799 14.249463
# ⋮   ⋮    ⋮     ⋮
# 76  BGR  375   19.475000
# 77  BUR  371   13.475676
# 78  PSE  365   10.146814
# 79  OKC  346   30.568807
# 80  SJC  329   10.103659
# 81  TUL  315   34.906355
# 82  OAK  312   13.344051
# 83  BHM  297   29.694853
# 84  SMF  284   18.691489
# 85  AVL  275    8.190114
# 86  ACK  265    6.456604
# 87  ABQ  254   13.740157
# 88  MVY  221    7.051643
# 89  EGE  213   15.495192
# 90  CRW  138   17.000000
# 91  CAE  116   35.570093
# 92  ILM  110   19.416667
# 93  TVC  101   22.083333
# 94  MYR   59   15.758621
# 95  CHO   52   21.391304
# 96  BZN   36   11.457143
# 97  JAC   25   26.545455
# 98  PSP   19   -2.944444
# 99  EYW   17    3.647059
# 100 HDN   15   12.285714
# 101 MTJ   15   17.642857
# 102 SBN   10   21.100000
# 103 ANC    8   12.875000
# 104 LEX    1   -9.000000
# 105 LGA    1         NaN

# %% [markdown]
# Under the hood, `x %>% f(y)` turns into `f(x, y)`, and `x %>% f(y) %>% g(z)` turns into `g(f(x, y), z)` and so on.
#
# You can even plot the data by adding a `ggplot` command at the end.

# %%
#options(repr.plot.width=6, repr.plot.height=4) # to ensure we do not get very large plots

group_by(flights, month) %>%
    summarize(delay = mean(dep_delay, na.rm = TRUE)) %>%
    ggplot() +
        geom_bar(mapping = aes(x=factor(month), y=delay), stat = "identity") +
        labs(x = "month", y = "average delay (in minutes)")
# Out:
# plot without title

# %%
# can you fill in this code to get a bar plot of
# average arrival delay by destination airport
# for the top 10 airports by traffic volume?

# group_by() %>%
#    summarize() %>%
#    arrange() %>%
#    slice() %>%
#    ggplot() +
#        geom_bar() +
#        xlab("destination airport") +
#        ylab("average arrival delay in minutes")

# %%
# airports, total flights, mean distance, and standard deviation of distance
# sorted in descending order of mean distance
group_by(flights, dest) %>%
    summarize(count = n(), sd = sd(distance), mean_distance = mean(distance)) %>%
    arrange(desc(mean_distance))
# Out:
#     dest count sd        mean_distance
# 1   HNL    707 10.001783 4972.675
# 2   ANC      8  0.000000 3370.000
# 3   SFO  13331 10.216858 2577.924
# 4   OAK    312  0.000000 2576.000
# 5   SJC    329  0.000000 2569.000
# 6   SMF    284  0.000000 2521.000
# 7   LAX  16174  9.657222 2468.622
# 8   BUR    371  0.000000 2465.000
# 9   LGB    668  0.000000 2465.000
# 10  PDX   1354  9.880313 2445.566
# 11  SAN   2737 10.346588 2437.299
# 12  SNA    825  0.000000 2434.000
# 13  SEA   3923  9.979116 2412.665
# 14  PSP     19  0.000000 2378.000
# 15  LAS   5997  9.913856 2240.961
# 16  PHX   4656  9.856062 2141.303
# 17  SLC   2467  7.363589 1986.987
# 18  BZN     36  0.000000 1882.000
# 19  JAC     25  5.537749 1875.600
# 20  ABQ    254  0.000000 1826.000
# 21  MTJ     15  0.000000 1795.000
# 22  EGE    213 10.549066 1735.709
# 23  HDN     15  0.000000 1728.000
# 24  STT    522  5.291656 1626.983
# 25  PSE    365  0.000000 1617.000
# 26  DEN   7266  7.981494 1614.678
# 27  SJU   5819  3.869986 1599.834
# 28  BQN    896  4.239051 1578.983
# 29  SAT    686  9.000096 1578.341
# 30  AUS   2439  8.318982 1514.253
# ⋮   ⋮    ⋮     ⋮         ⋮
# 76  ILM    110 0.000000  500.00000
# 77  DTW   9384 7.581811  498.12852
# 78  CMH   3524 7.071074  476.55505
# 79  GSO   1606 7.352531  449.84184
# 80  CRW    138 0.000000  444.00000
# 81  RDU   8163 5.378799  426.75769
# 82  CLE   4573 8.282101  414.17428
# 83  CAK    864 0.000000  397.00000
# 84  BGR    375 0.000000  378.00000
# 85  PIT   2875 7.731472  334.06122
# 86  CHO     52 0.000000  305.00000
# 87  BUF   4681 7.724076  296.80837
# 88  ORF   1536 4.043022  288.52344
# 89  RIC   2454 6.497803  281.40465
# 90  PWM   2352 5.633014  276.12840
# 91  BTV   2589 2.538673  265.09154
# 92  ROC   2416 7.452263  259.25083
# 93  IAD   5700 6.774477  224.84684
# 94  DCA   9705 5.588415  211.00618
# 95  MHT   1009 4.870863  207.02973
# 96  SYR   1761 5.305292  205.92164
# 97  ACK    265 0.000000  199.00000
# 98  BOS  15508 6.878423  190.63696
# 99  BWI   1781 6.920632  179.41830
# 100 MVY    221 0.000000  173.00000
# 101 PVD    376 0.000000  160.00000
# 102 ALB    439 0.000000  143.00000
# 103 BDL    443 0.000000  116.00000
# 104 PHL   1632 2.696727   94.32353
# 105 LGA      1       NA   17.00000

# %%
# first attempt at a scatter plot of
# distance vs. arrival delay

ggplot(flights) +
    geom_point(mapping = aes(x = distance, y = arr_delay))
# Out:
# Warning message:
# “Removed 9430 rows containing missing values (geom_point).”
# plot without title

# %%
# can you fill in this code to get a scatter plot of
# airport distance vs. average arrival delay after
# grouping by destination airport?
# also superimpose on the scatter plot a smoothed plot

# change 1: skip Honolulu (HNL)
# change 2: only airport less than 4000 miles away
# change 3: only airport less than 1000 miles away

# group_by() %>%
#    summarize() %>%
#    ggplot() +
#        geom_point() +
#        geom_smooth()
